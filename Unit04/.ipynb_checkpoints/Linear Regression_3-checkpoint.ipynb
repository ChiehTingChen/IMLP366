# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## 3. Nonlinear
#
# $$f(x) = \sin(3.2x) + 0.8x$$

# %% [markdown]
# ### 3. 生成假資料

# %%
x = np.linspace(0, 5, 100)
y = np.sin(3.2*x) + 0.8*x + 0.3*np.random.randn(100)

# %%
plt.scatter(x,y)

# %% [markdown]
# #### nonlinear

# %%
regr_lin = LinearRegression()

# %%
X = x.reshape(-1, 1)
print(X.shape)
# Out:
# (100, 1)

# %%
regr_lin.fit(X,y)
# Out:
# LinearRegression()

# %%
Y=regr_lin.predict(X)
plt.scatter(x,y)
plt.plot(x,Y , color='r')
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.512507884190408

# %% [markdown]
# 果然超級不準, 該如何是好?

# %% [markdown]
# #### 多項式
#
# 多項式5次方

# %% [markdown]
# $$\widehat{y}=xw+b=w_{1}x_{1}+w_{2}x_{1}^{2}+w_{3}x_{1}^{3}+w_{4}x_{1}^{4}+w_{5}x_{1}^{5}+b$$

# %%
print(x.shape)
# Out:
# (100,)

# %%
X_poly = np.array([[k, k**2, k**3, k**4, k**5] for k in x])  # add k**6 to try it
print(X_poly.shape)
# Out:
# (100, 5)

# %%
regr_poly = LinearRegression()

# %%
regr_poly.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.plot(x, regr_poly.predict(X_poly), 'r')

# %%
print('Coefficients: ', regr_poly.coef_)
print('interception: ', regr_poly.intercept_)
# Out:
# Coefficients:  [-0.84085625  0.97329713 -0.29588864  0.04771417 -0.002966  ]
# interception:  0.9581472251513601

# %%
W=regr_poly.coef_
b=regr_poly.intercept_
np.dot(X_poly,W.T)+b
# Out:
# array([0.95814723, 0.91812458, 0.88284283, 0.85208431, 0.82563855,
#        0.80330218, 0.78487883, 0.77017899, 0.75901989, 0.75122539,
#        0.74662587, 0.74505813, 0.74636521, 0.75039635, 0.75700682,
#        0.76605781, 0.77741635, 0.79095515, 0.8065525 , 0.82409216,
#        0.84346322, 0.86456001, 0.88728198, 0.91153355, 0.93722404,
#        0.96426753, 0.99258273, 1.02209288, 1.05272564, 1.08441295,
#        1.11709093, 1.15069977, 1.18518359, 1.22049034, 1.25657167,
#        1.29338284, 1.33088255, 1.3690329 , 1.40779919, 1.44714988,
#        1.48705641, 1.52749312, 1.56843712, 1.60986817, 1.65176858,
#        1.69412308, 1.73691869, 1.78014464, 1.82379221, 1.86785465,
#        1.91232703, 1.95720616, 2.00249043, 2.04817974, 2.09427534,
#        2.14077973, 2.18769658, 2.23503052, 2.28278714, 2.33097278,
#        2.37959444, 2.4286597 , 2.47817655, 2.52815331, 2.5785985 ,
#        2.6295207 , 2.68092848, 2.73283024, 2.78523414, 2.83814793,
#        2.89157885, 2.94553355, 3.00001792, 3.05503701, 3.1105949 ,
#        3.16669456, 3.22333779, 3.28052504, 3.33825534, 3.39652617,
#        3.45533331, 3.51467077, 3.57453067, 3.63490307, 3.69577592,
#        3.7571349 , 3.81896332, 3.88124201, 3.94394916, 4.00706027,
#        4.07054799, 4.13438199, 4.1985289 , 4.26295213, 4.32761179,
#        4.39246456, 4.45746359, 4.52255835, 4.58769454, 4.65281399])

# %%
regr_poly.predict(X_poly)
# Out:
# array([0.95814723, 0.91812458, 0.88284283, 0.85208431, 0.82563855,
#        0.80330218, 0.78487883, 0.77017899, 0.75901989, 0.75122539,
#        0.74662587, 0.74505813, 0.74636521, 0.75039635, 0.75700682,
#        0.76605781, 0.77741635, 0.79095515, 0.8065525 , 0.82409216,
#        0.84346322, 0.86456001, 0.88728198, 0.91153355, 0.93722404,
#        0.96426753, 0.99258273, 1.02209288, 1.05272564, 1.08441295,
#        1.11709093, 1.15069977, 1.18518359, 1.22049034, 1.25657167,
#        1.29338284, 1.33088255, 1.3690329 , 1.40779919, 1.44714988,
#        1.48705641, 1.52749312, 1.56843712, 1.60986817, 1.65176858,
#        1.69412308, 1.73691869, 1.78014464, 1.82379221, 1.86785465,
#        1.91232703, 1.95720616, 2.00249043, 2.04817974, 2.09427534,
#        2.14077973, 2.18769658, 2.23503052, 2.28278714, 2.33097278,
#        2.37959444, 2.4286597 , 2.47817655, 2.52815331, 2.5785985 ,
#        2.6295207 , 2.68092848, 2.73283024, 2.78523414, 2.83814793,
#        2.89157885, 2.94553355, 3.00001792, 3.05503701, 3.1105949 ,
#        3.16669456, 3.22333779, 3.28052504, 3.33825534, 3.39652617,
#        3.45533331, 3.51467077, 3.57453067, 3.63490307, 3.69577592,
#        3.7571349 , 3.81896332, 3.88124201, 3.94394916, 4.00706027,
#        4.07054799, 4.13438199, 4.1985289 , 4.26295213, 4.32761179,
#        4.39246456, 4.45746359, 4.52255835, 4.58769454, 4.65281399])

# %% [markdown]
# #### RBF
#
# $$\phi_i = e^{-\| x - c_i \|^2/2\sigma^2}$$

# %%
# normal distrubution
def RBF(x, center, sigma):
    k = np.exp(-(x - center)**2/(2*sigma**2))
    return k

# %%
sigma = 0.3

# %%
X_rbf = np.array([[RBF(k, .5, sigma), 
                  RBF(k, 1.5, sigma),
                  RBF(k, 2.5, sigma),
                  RBF(k, 3.5, sigma),
                  RBF(k, 4.5, sigma)] for k in x])

# %%
regr_rbf = LinearRegression()

# %%
regr_rbf.fit(X_rbf, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.plot(x, regr_rbf.predict(X_rbf), 'r')

# %%
print('Coefficients: ', regr_rbf.coef_)
print('interception: ', regr_rbf.intercept_)
# Out:
# Coefficients:  [-0.98264481 -2.131239    1.02473349  0.05571339  3.15486861]
# interception:  1.9924223404338643

# %% [markdown]
# #### Comparison

# %%
Y_lin = regr_lin.predict(X)
Y_poly = regr_poly.predict(X_poly)
Y_rbf = regr_rbf.predict(X_rbf)

# %%
plt.scatter(x,y)

plt.plot(x, Y_lin, label='linear')
plt.plot(x, Y_poly, label='polynomial')
plt.plot(x, Y_rbf, label='rbf')
plt.legend()

# %% [markdown]
# ## 請計算模型的MSE

# %%
print(np.sum((regr_lin.predict(X)-y)**2) / len(y))
# Out:
# 0.5939286270763321

# %%
print(np.sum((regr_poly.predict(X_poly)-y)**2) / len(y))
# Out:
# 0.5200681969326918

# %%
print(np.sum((regr_rbf.predict(X_rbf)-y)**2) / len(y))
# Out:
# 0.28991309399783594
